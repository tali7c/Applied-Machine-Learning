# %% [markdown]
# # Applied Machine Learning (CSAI2017P) — Lab Assignment 10
# ## Clustering Medical Images and Crop Disease Classification
#
# Experiments 13–14 · CO2, CO4 · **10 marks**
#
# | | |
# |---|---|
# | Name | *fill in* |
# | SAP ID | *fill in* |
# | Batch | *fill in* |
# | Due | announced in the lab |
# | Lab quiz | LQ10, after submission |
#
# **Datasets:** B1 (digits), B3 (Breast Cancer), B4 (PlantVillage leaf subset)
#
# ---
#
# ### Before you start
# - Attempt **2 of 3** in Section A, **1 of 2** in Section B. Section C is compulsory.
# - Fit every transformer inside a `Pipeline`. Never fit on the test set.
# - Set `random_state` wherever the question asks for reproducibility.
# - Every question wants a short written observation, not just a number.
# - Restart the kernel and run top-to-bottom before you submit.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

RANDOM_STATE = 0
np.random.seed(RANDOM_STATE)

for m in (np, pd, sklearn):
    print(f"{m.__name__:12s} {m.__version__}")

# %% [markdown]
# ## Load the data
#
# Replace with the loader for this assignment's anchor dataset — see `Anchor-Datasets.pdf` for the snippets.

# %%
# TODO: load the dataset for this assignment
# from sklearn.datasets import ...
# df = pd.read_csv('data/...')

# %% [markdown]
# ---
#
# # Section A — attempt any 2 of 3 (2 marks each)
#
# *attempt 2 of 3*

# %% [markdown]
# ## A1. Cluster the digits  &nbsp;&nbsp;`[2 marks]`
#
# *Dataset: B1 (digits), labels withheld.*
#
# a. Scale the features and run K-means with k=10.
# b. Report inertia and the silhouette score.
# c. State in two lines why you cannot report accuracy here.

# %%
# A1 — code

# %% [markdown]
# **Observation (A1):**
#
# > *write 2–6 lines here*

# %% [markdown]
# ## A2. Choosing k  &nbsp;&nbsp;`[2 marks]`
#
# *Dataset: B1 (digits).*
#
# a. Run K-means for k ∈ {2,…,15} and plot inertia and silhouette against k.
# b. State the k each criterion suggests.
# c. In two lines, say what you would conclude if the two criteria disagreed.

# %%
# A2 — code

# %% [markdown]
# **Observation (A2):**
#
# > *write 2–6 lines here*

# %% [markdown]
# ## A3. Load the leaf images  &nbsp;&nbsp;`[2 marks]`
#
# *Dataset: B4 (PlantVillage tomato subset).*
#
# a. Load the subset, resize to 64×64 and report the number of images per class.
# b. Display one image per class in a grid.
# c. State in two lines whether the classes are balanced and what you would do if not.

# %%
# A3 — code

# %% [markdown]
# **Observation (A3):**
#
# > *write 2–6 lines here*

# %% [markdown]
# ---
#
# # Section B — attempt any 1 of 2 (4 marks each)
#
# *attempt 1 of 2*

# %% [markdown]
# ## B1. Do the clusters mean anything  &nbsp;&nbsp;`[4 marks]`
#
# *Dataset: B1 or B3, your choice.*
#
# a. Cluster the data at your chosen k, then compare the clustering with the withheld labels using the adjusted Rand index and a cluster-versus-label crosstab.
# b. Report ARI and identify one cluster that is nearly pure and one that mixes classes.
# c. In 6–8 lines, explain what ARI measures and why a low ARI does not automatically mean the clustering is useless.

# %%
# B1 — code

# %% [markdown]
# **Observation (B1):**
#
# > *write 2–6 lines here*

# %% [markdown]
# ## B2. Leaf disease classifier  &nbsp;&nbsp;`[4 marks]`
#
# *Dataset: B4.*
#
# a. Build a classifier on flattened resized images or on simple colour-histogram features; use a stratified split.
# b. Report macro-F1 and the per-class F1 table.
# c. Show four misclassified leaves and explain in 6–8 lines what confuses the model.

# %%
# B2 — code

# %% [markdown]
# **Observation (B2):**
#
# > *write 2–6 lines here*

# %% [markdown]
# ---
#
# # Section C — compulsory (2 marks)
#
# *compulsory*

# %% [markdown]
# ## C1. What would you tell the farmer  &nbsp;&nbsp;`[2 marks]`
#
# *Dataset: B4.*
#
# a. State your model's macro-F1 and its worst per-class F1.
# b. In 4–6 lines, write what you would honestly tell someone about to rely on this model in a field, including one thing it will get wrong.

# %%
# C1 — code

# %% [markdown]
# **Observation (C1):**
#
# > *write 2–6 lines here*

# %% [markdown]
# ---
#
# ## Self-check before submitting
#
# - [ ] Kernel restarted and run top-to-bottom, all outputs visible
# - [ ] Every attempted question has a written observation
# - [ ] No transformer fitted outside a pipeline
# - [ ] Metrics reported with units where they have any
# - [ ] File named `AML_LA10_<SAPID>.ipynb`
